# %%
import pandas as pd

# %%
titanic_train = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dy = titanic_train.dtypes
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy['Pclass']
# Out:
# dtype('int64')

# %%
dy[0:4]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# dtype: object

# %%
dy[0]
# Out:
# dtype('int64')

# %%
dy[0:20:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Age'][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
titanic_train['Age'][::-1]
# Out:
# 890    32.0
# 889    26.0
# 888     NaN
# 887    19.0
# 886    27.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_train['Age'][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_20084/571722093.py in <module>
# ----> 1 titanic_train['Age'][-1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
titanic_train['Age'][::2]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 6      54.0
# 8      27.0
#        ...
# 882    22.0
# 884    25.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 446, dtype: float64

# %%
list(titanic_train['Age'][::2])
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan,
#  16.0,
#  nan,
#  44.0,
#  26.0,
#  1.0,
#  nan,
#  nan,
#  61.0,
#  1.0,
#  56.0,
#  nan,
#  30.0,
#  nan,
#  9.0,
#  4.0,
#  nan,
#  40.0,
#  32.0,
#  19.0,
#  44.0,
#  nan,
#  nan,
#  28.0,
#  34.0,
#  18.0,
#  32.0,
#  16.0,
#  24.0,
#  22.0,
#  nan,
#  27.0,
#  32.0,
#  16.0,
#  51.0,
#  38.0,
#  19.0,
# ...

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train_cat = titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]
titanic_train_cat
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train_cat.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic_train[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
titanic_train[['Name','Fare']]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas  13.0000
# 887                       Graham, Miss. Margaret Edith  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889                              Behr, Mr. Karl Howell  30.0000
# 890                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 2 columns]

# %%
titanic_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
import numpy as np

# %%
titanic_train_age_null = np.where(titanic_train['Age'].isnull() == True)  # list of indexes
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train[titanic_train['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_train[['Name','Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
titanic_train.iloc[titanic_train_age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_train.iloc[5] # iloc for rowwise filtration
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
titanic_train.iloc[[1,4,6,8,9,14,56]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 9            10         1       2
# 14           15         0       3
# 56           57         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 56                                  Rugg, Miss. Emily  female  21.0      0
#
#     Parch      Ticket     Fare Cabin Embarked
# ...

# %%
titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Age'] == 24]
# Out:
#      PassengerId  Survived  Pclass  \
# 89            90         0       3
# 118          119         0       1
# 127          128         1       3
# 139          140         0       1
# 142          143         1       3
# 199          200         0       2
# 210          211         0       3
# 234          235         0       2
# 247          248         1       2
# 293          294         0       3
# 294          295         0       3
# 310          311         1       1
# 316          317         1       2
# 341          342         1       1
# 345          346         1       2
# 369          370         1       1
# 394          395         1       3
# 437          438         1       2
# 499          500         0       3
# 514          515         0       3
# 565          566         0       3
# 600          601         1       2
# 615          616         1       2
# 641          642         1       1
# 655          656         0       2
# ...

# %%
titanic_train[titanic_train['Age'] == 24][['Name']]
# Out:
#                                                   Name
# 89                              Celotti, Mr. Francesco
# 118                           Baxter, Mr. Quigg Edmond
# 127                          Madsen, Mr. Fridtjof Arne
# 139                                 Giglio, Mr. Victor
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199             Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                     Ali, Mr. Ahmed
# 234                  Leyson, Mr. Robert William Norman
# 247                    Hamalainen, Mrs. William (Anna)
# 293                                Haas, Miss. Aloisia
# 294                                   Mineff, Mr. Ivan
# 310                     Hays, Miss. Margaret Bechstein
# 316                Kantor, Mrs. Sinai (Miriam Sternin)
# 341                     Fortune, Miss. Alice Elizabeth
# 345                      Brown, Miss. Amelia "Mildred"
# 369                      Aubart, Mme. Leontine Pauline
# ...

# %%
titanic_train[titanic_train['Age'] == min(titanic_train['Age'])]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
titanic_train[titanic_train['Age'] == min(titanic_train['Age'])]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Cabin'].isnull()][['Age','Cabin']]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train[(titanic_train['Survived'] == 1) & (titanic_train['Sex'] == 'male')][['Name','Sex']]
# Out:
#                                 Name   Sex
# 17      Williams, Mr. Charles Eugene  male
# 21             Beesley, Mr. Lawrence  male
# 23      Sloper, Mr. William Thompson  male
# 36                  Mamee, Mr. Hanna  male
# 55                 Woolner, Mr. Hugh  male
# ..                               ...   ...
# 838                  Chip, Mr. Chang  male
# 839             Marechal, Mr. Pierre  male
# 857           Daly, Mr. Peter Denis   male
# 869  Johnson, Master. Harold Theodor  male
# 889            Behr, Mr. Karl Howell  male
#
# [109 rows x 2 columns]

# %%
titanic_train['new_col'] = 'suddh'

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
l=[0,1,2,3,4]

# %%
pd.Series(l)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
d={'name':'hamza', 'sex':'male', 'age': 27}

# %%
pd.DataFrame(d, index = ['name', 'sex', 'age'])
# Out:
#        name   sex  age
# name  hamza  male   27
# sex   hamza  male   27
# age   hamza  male   27

# %%
pd.Series(d)
# Out:
# name    hamza
# sex      male
# age        27
# dtype: object

# %%
arr = np.random.randn(3,4)

# %%
arr
# Out:
# array([[ 1.81099174,  1.19618533, -0.56897776, -0.82180082],
#        [ 0.04584135,  0.10431811,  0.20010913, -1.331531  ],
#        [ 0.31658692, -0.94753226,  0.58340103,  2.33545238]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  1.810992  1.196185 -0.568978 -0.821801
# 1  0.045841  0.104318  0.200109 -1.331531
# 2  0.316587 -0.947532  0.583401  2.335452

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_20084/2396573727.py in <module>
# ----> 1 pd.Series(arr)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     437                     data = data.copy()
#     438             else:
# --> 439                 data = sanitize_array(data, index, dtype, copy)
#     440
#     441                 manager = get_option("mode.data_manager")
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     574                 subarr = maybe_infer_to_datetimelike(subarr)
#     575
# --> 576     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     577
#     578     if isinstance(subarr, np.ndarray):
#
# ...

# %%
pd.Series(np.array([4,5,66,7,8]))
# Out:
# 0     4
# 1     5
# 2    66
# 3     7
# 4     8
# dtype: int32

# %%
ser = pd.Series(np.array([4,5,66,7,8]), index = ['a','b','c','d','e'])

# %%
ser
# Out:
# a     4
# b     5
# c    66
# d     7
# e     8
# dtype: int32

# %%
ser['c']
# Out:
# 66

# %%
ser.iloc['d']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_20084/329122286.py in <module>
# ----> 1 ser.iloc['d']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1561             key = item_from_zerodim(key)
#    1562             if not is_integer(key):
# -> 1563                 raise TypeError("Cannot index by location index with a non-integer key")
#    1564
#    1565             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
ser[0]
# Out:
# 4

# %%
ser.loc['d']
# Out:
# 7

# %%
ser1 = pd.Series(np.array([4,5,66,7,8]), index = [41,55,644,72,89])

# %%
ser1
# Out:
# 41      4
# 55      5
# 644    66
# 72      7
# 89      8
# dtype: int32

# %%
ser1.iloc[41]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_20084/4267987467.py in <module>
# ----> 1 ser1.iloc[41]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
ser1.loc[41]
# Out:
# 4

# %%
df = pd.DataFrame(np.random.randint(3,6, (4,5)), index = ['a','b','c','d'], columns= ['x','y','z','u','v'])
df
# Out:
#    x  y  z  u  v
# a  5  3  5  4  4
# b  3  3  4  3  4
# c  5  5  5  4  5
# d  3  3  4  3  3

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  5  4
# d  4  3

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  5  4
# d  4  3

# %%
 df.iloc[2:4,2:4]
# Out:
#    z  u
# c  5  4
# d  4  3

# %%
df
# Out:
#    x  y  z  u  v
# a  5  3  5  4  4
# b  3  3  4  3  4
# c  5  5  5  4  5
# d  3  3  4  3  3

# %%
df['new'] = df['x'] + df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  5  3  5  4  4    8
# b  3  3  4  3  4    6
# c  5  5  5  4  5   10
# d  3  3  4  3  3    6

# %%
df.drop('x')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_20084/2917862228.py in <module>
# ----> 1 df.drop('x')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.drop('x', axis = 1)
# Out:
#    y  z  u  v  new
# a  3  5  4  4    8
# b  3  4  3  4    6
# c  5  5  4  5   10
# d  3  4  3  3    6

# %%
df
# Out:
#    x  y  z  u  v  new
# a  5  3  5  4  4    8
# b  3  3  4  3  4    6
# c  5  5  5  4  5   10
# d  3  3  4  3  3    6

# %%
df.drop('x', axis = 1, inplace = True) # for permanent deletion of row or column

# %%
df
# Out:
#    y  z  u  v  new
# a  3  5  4  4    8
# b  3  4  3  4    6
# c  5  5  4  5   10
# d  3  4  3  3    6

# %%
df.drop('c')
# Out:
#    y  z  u  v  new
# a  3  5  4  4    8
# b  3  4  3  4    6
# d  3  4  3  3    6

# %%
df
# Out:
#    y  z  u  v  new
# a  3  5  4  4    8
# b  3  4  3  4    6
# c  5  5  4  5   10
# d  3  4  3  3    6

# %%
df.drop('c', inplace = True)

# %%
df
# Out:
#    y  z  u  v  new
# a  3  5  4  4    8
# b  3  4  3  4    6
# d  3  4  3  3    6

# %%
df
# Out:
#    y  z  u  v  new
# a  3  5  4  4    8
# b  3  4  3  4    6
# d  3  4  3  3    6

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5), index = ['a','b','c','d'], columns = ['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
df.values
# Out:
# array([[ 0.66698806,  0.02581308, -0.77761941,  0.94863382,  0.70167179],
#        [-1.05108156, -0.36754812, -1.13745969, -1.32214752,  1.77225828],
#        [-0.34745899,  0.67014016,  0.32227152,  0.06034293, -1.04345   ],
#        [-1.00994188,  0.44173637,  1.12887685, -1.83806777, -0.93876863]])

# %%
df.values[df.values<0] # Printing all the negative values
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
neg_val = df.values[df.values<0]

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] in neg_val:
            print(i,j, df[i][j])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
d = {'key1':[1,2,3,4,np.nan], 'key2': ['sudh', 'kumar', np.nan,5,6], 'key3': [np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=0) #atleast zero non na value in a row
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1) #atleast one non na value in a row
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)  #atleast two non na value in a row
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)   #atleast three non na value in a row
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(thresh=4)   #atleast four non na value in a row
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.dropna(thresh=3 , axis=1)   #atleast three non na value in column
# Out:
#    key1   key2
# 0   1.0   sudh
# 1   2.0  kumar
# 2   3.0    NaN
# 3   4.0      5
# 4   NaN      6

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.fillna('sudh')
# Out:
#    key1   key2  key3
# 0   1.0   sudh  sudh
# 1   2.0  kumar  sudh
# 2   3.0   sudh  sudh
# 3   4.0      5   3.0
# 4  sudh      6   8.0

# %%
df.fillna(444)
# Out:
#     key1   key2   key3
# 0    1.0   sudh  444.0
# 1    2.0  kumar  444.0
# 2    3.0    444  444.0
# 3    4.0      5    3.0
# 4  444.0      6    8.0

# %%
df.fillna(value = df['key1'].mean())
# Out:
#    key1   key2  key3
# 0   1.0   sudh   2.5
# 1   2.0  kumar   2.5
# 2   3.0    2.5   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
d1 = {'name':['sudh','vishal', 'umang', 'vishal', 'umang'],
      'maild_id':['sudh@gmail.com', 'vishal@gmail.com', 'umang@gmail.com', 'vishal@gmail.com', 'umang@gmail.com'],
      'salary':[100,200,500,400,800]
}
df1 = pd.DataFrame(d1)
df1
# Out:
#      name          maild_id  salary
# 0    sudh    sudh@gmail.com     100
# 1  vishal  vishal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     400
# 4   umang   umang@gmail.com     800

# %%
df1.groupby('name').mean()
# Out:
#         salary
# name
# sudh     100.0
# umang    650.0
# vishal   300.0

# %%
df1.groupby('maild_id').mean()
# Out:
#                   salary
# maild_id
# sudh@gmail.com     100.0
# umang@gmail.com    650.0
# vishal@gmail.com   300.0

# %%
df1.groupby('maild_id').sum()
# Out:
#                   salary
# maild_id
# sudh@gmail.com       100
# umang@gmail.com     1300
# vishal@gmail.com     600

# %%
df1.groupby('maild_id').describe()
# Out:
#                  salary
#                   count   mean         std    min    25%    50%    75%    max
# maild_id
# sudh@gmail.com      1.0  100.0         NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  650.0  212.132034  500.0  575.0  650.0  725.0  800.0
# vishal@gmail.com    2.0  300.0  141.421356  200.0  250.0  300.0  350.0  400.0

# %%
df1.groupby('maild_id').describe().loc[['umang@gmail.com']]
# Out:
#                 salary
#                  count   mean         std    min    25%    50%    75%    max
# maild_id
# umang@gmail.com    2.0  650.0  212.132034  500.0  575.0  650.0  725.0  800.0

# %%
df1.groupby('maild_id').describe().loc[['umang@gmail.com']]['salary']['mean']
# Out:
# maild_id
# umang@gmail.com    650.0
# Name: mean, dtype: float64

# %%
df1.groupby('maild_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.000000
#         mean     650.000000
#         std      212.132034
#         min      500.000000
#         25%      575.000000
#         50%      650.000000
#         75%      725.000000
#         max      800.000000
# Name: umang@gmail.com, dtype: float64

# %%
df1.groupby('maild_id').describe().loc['umang@gmail.com'][1]
# Out:
# 650.0

# %%
df1.groupby('maild_id').describe()
# Out:
#                  salary
#                   count   mean         std    min    25%    50%    75%    max
# maild_id
# sudh@gmail.com      1.0  100.0         NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  650.0  212.132034  500.0  575.0  650.0  725.0  800.0
# vishal@gmail.com    2.0  300.0  141.421356  200.0  250.0  300.0  350.0  400.0

# %%
df1.groupby('maild_id').describe().T   #Transpose
# Out:
# maild_id      sudh@gmail.com  umang@gmail.com  vishal@gmail.com
# salary count             1.0         2.000000          2.000000
#        mean            100.0       650.000000        300.000000
#        std               NaN       212.132034        141.421356
#        min             100.0       500.000000        200.000000
#        25%             100.0       575.000000        250.000000
#        50%             100.0       650.000000        300.000000
#        75%             100.0       725.000000        350.000000
#        max             100.0       800.000000        400.000000

# %%
arr1 = np.random.randn(3,4)
arr2 = np.random.randn(3,4)
arr3 = np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1, columns = ['A','B','C','D'], index = [0,1,2])
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2 = pd.DataFrame(arr2, columns = ['A','B','C','D'], index = [3,4,5])
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
df3 = pd.DataFrame(arr3, columns = ['A','B','C','D'], index = [6,7,8])
df3
# Out:
#           A         B         C         D
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
df3
# Out:
#           A         B         C         D
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
df4 = pd.concat([df1,df2,df3])  # Rowwise Concatenation

# %%
df5= pd.concat([df1,df2,df3], axis = 1) # Column wise Concatenation

# %%
df4
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
df4.iloc[0]
# Out:
# A   -0.201841
# B    1.045371
# C    0.538162
# D    0.812119
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
# A   -0.201841
# B    1.045371
# C    0.538162
# D    0.812119
# Name: 0, dtype: float64

# %%
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119       NaN       NaN       NaN
# 1  0.241106 -0.952510 -0.136267  1.267248       NaN       NaN       NaN
# 2  0.173634 -1.223255  1.415320  0.457711       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.728876  1.968435 -0.547788
# 4       NaN       NaN       NaN       NaN -2.506230  0.146960  0.606195
# 5       NaN       NaN       NaN       NaN  0.013422  0.935945  0.420623
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df5['A']
# Out:
#           A         A         A
# 0 -0.201841       NaN       NaN
# 1  0.241106       NaN       NaN
# 2  0.173634       NaN       NaN
# 3       NaN  0.728876       NaN
# 4       NaN -2.506230       NaN
# 5       NaN  0.013422       NaN
# 6       NaN       NaN -0.071324
# 7       NaN       NaN -0.420844
# 8       NaN       NaN  0.512137

# %%
df5.iloc[:,4]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3    0.728876
# 4   -2.506230
# 5    0.013422
# 6         NaN
# 7         NaN
# 8         NaN
# Name: A, dtype: float64

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
df3
# Out:
#           A         B         C         D
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
pd.concat([df1,df2,df3], axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119       NaN       NaN       NaN
# 1  0.241106 -0.952510 -0.136267  1.267248       NaN       NaN       NaN
# 2  0.173634 -1.223255  1.415320  0.457711       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.728876  1.968435 -0.547788
# 4       NaN       NaN       NaN       NaN -2.506230  0.146960  0.606195
# 5       NaN       NaN       NaN       NaN  0.013422  0.935945  0.420623
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat([df1,df2,df3], axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119  0.000000  0.000000  0.000000
# 1  0.241106 -0.952510 -0.136267  1.267248  0.000000  0.000000  0.000000
# 2  0.173634 -1.223255  1.415320  0.457711  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.728876  1.968435 -0.547788
# 4  0.000000  0.000000  0.000000  0.000000 -2.506230  0.146960  0.606195
# 5  0.000000  0.000000  0.000000  0.000000  0.013422  0.935945  0.420623
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1, columns = ['A','B','C','D'], index = [0,1,2])
df22 = pd.DataFrame(arr2, columns = ['A','B','C','D'], index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22, on = 'A')
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
df1 = pd.DataFrame({'key':['K0', 'K8','K2','K3'],
                    'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3']})

df2 = pd.DataFrame({'key':['K0', 'K1','K2','K3'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(df1,df2, on = 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(df1,df2, on = 'key', how = 'left')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(df1,df2, on = 'key', how = 'right')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
pd.merge(df1,df2, on = 'key', how = 'outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
df1 = pd.DataFrame({'key1':['K0', 'K0','K1','K2'],
                    'key2':['K0','K1','K0','K1'],
                    'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3']})

df2 = pd.DataFrame({'key1':['K0', 'K1','K1','K2'],
                    'key2':['K0','K0','K0','K0'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2, on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A':['A0', 'A1','A2'],
                    'B':['B0','B1','B2']},
                    index = ['K0','K1','K2'])

df2 = pd.DataFrame({'C':['C0','C2','C3'],
                    'D':['D0','D2','D3']},
                    index = ['K0','K2','K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df1.join(df2, how = 'right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %%
df1.join(df2, how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
# Difference between merge and join
# Merge will merge on the basis of columns
# Join will join on the basis of rows

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.randn(10,4), index = pd.date_range('2021-07-18', periods = 10), columns = ['a','b','c','d'] )
df
# Out:
#                    a         b         c         d
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new'] = df['c'] + df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913

# %%
df['new_col_square_d'] = df['d'].apply(lambda x : x**2)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_square_d
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725          5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012          0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950          0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787          0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477          0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910          1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169          2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073          1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928          2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913          1.291693

# %%
df['new_col_square_d_log'] = df['d'].apply(lambda x : np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log
# 2021-07-18          5.490876                   NaN
# 2021-07-19          0.957425                   NaN
# 2021-07-20          0.243454                   NaN
# 2021-07-21          0.060376             -1.403582
# ...

# %%
def test(x):
    if (x<0):
        return x
    else:
        return np.log(x)

# %%
df['new_col_square_d_log_1'] = df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1
# 2021-07-18          5.490876                   NaN               -2.343262
# 2021-07-19          0.957425                   NaN               -0.978481
# ...

# %%
def test1(x):
    if x<0:
        return 1
    else:
        return 0

# %%
df['new_col_a'] = df['a'].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          5.490876                   NaN               -2.343262
# 2021-07-19          0.957425                   NaN               -0.978481
# ...

# %%
df.sort_values(by = 'b')
# Out:
#                    a         b         c         d       new  \
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-23          1.776298              0.287266                0.287266
# 2021-07-25          1.220096                   NaN               -1.104579
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          5.490876                   NaN               -2.343262
# 2021-07-19          0.957425                   NaN               -0.978481
# ...

# %%
df['new_date'] = df.index

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          5.490876                   NaN               -2.343262
# 2021-07-19          0.957425                   NaN               -0.978481
# ...

# %%
df.dtypes
# Out:
# a                                float64
# b                                float64
# c                                float64
# d                                float64
# new                              float64
# new_col_square_d                 float64
# new_col_square_d_log             float64
# new_col_square_d_log_1           float64
# new_col_a                          int64
# new_date                  datetime64[ns]
# dtype: object

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          5.490876                   NaN               -2.343262
# 2021-07-19          0.957425                   NaN               -0.978481
# ...

# %%
df['new_column'] = df.index.day_name()

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          5.490876                   NaN               -2.343262
# 2021-07-19          0.957425                   NaN               -0.978481
# ...

# %%
df.groupby(by = 'new_column').count()
# Out:
#             a  b  c  d  new  new_col_square_d  new_col_square_d_log  \
# new_column
# Friday      1  1  1  1    1                 1                     1
# Monday      2  2  2  2    2                 2                     0
# Saturday    1  1  1  1    1                 1                     1
# Sunday      2  2  2  2    2                 2                     0
# Thursday    1  1  1  1    1                 1                     1
# Tuesday     2  2  2  2    2                 2                     0
# Wednesday   1  1  1  1    1                 1                     1
#
#             new_col_square_d_log_1  new_col_a  new_date  day  month  year
# new_column
# Friday                           1          1         1    1      1     1
# Monday                           2          2         2    2      2     2
# Saturday                         1          1         1    1      1     1
# Sunday                           2          2         2    2      2     2
# ...
