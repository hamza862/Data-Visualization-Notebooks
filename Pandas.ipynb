# %%
import pandas as pd

# %%
pd = pd.read_csv('E:\Pictures\Sample-Spreadsheet-1000-rows.csv', encoding='latin1')
pd
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2       4                                               R380
# 3       5                           Holmes HEPA Air Purifier
# 4       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..    ...                                                ...
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# 1         Barry French    293    46.71    8.69   2.99           Nunavut
# ...

# %%
pd.head()
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37

# %%
pd.head(2)
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39

# %%
pd.head(20)
# Out:
#      1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0    2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1    3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2    4                                               R380      Clay Rozendal
# 3    5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4    6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5    7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6    8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7    9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8   10                                          Xerox 198    Dorothy Badders
# 9   11                                         Xerox 1980    Neola Schneider
# 10  12    Advantus Map Pennant Flags and Round Head Tacks    Neola Schneider
# ...

# %%
pd.tail()
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25  38.94     35           Nunavut  \
# 994      Dennis Bolton  48165  -147.27   6.48   9.54  British Columbia
# 995  Anthony O'Donnell  48197   154.74  40.97  14.45  British Columbia
# 996     Barbara Fisher  48484    67.96  16.48   1.99  British Columbia
# 997     Barbara Fisher  48484   133.83  20.24   6.67  British Columbia
# 998     Barbara Fisher  48484   153.80  18.97   9.03  British Columbia
#
#     Storage & Organization   0.8
# 994                  Paper  0.37
# 995     Office Furnishings  0.57
# 996   Computer Peripherals  0.42
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample-Spreadsheet-1000-rows.csv', encoding = 'latin1')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df.head()
df1
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37

# %%
df.tail()
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25  38.94     35           Nunavut  \
# 994      Dennis Bolton  48165  -147.27   6.48   9.54  British Columbia
# 995  Anthony O'Donnell  48197   154.74  40.97  14.45  British Columbia
# 996     Barbara Fisher  48484    67.96  16.48   1.99  British Columbia
# 997     Barbara Fisher  48484   133.83  20.24   6.67  British Columbia
# 998     Barbara Fisher  48484   153.80  18.97   9.03  British Columbia
#
#     Storage & Organization   0.8
# 994                  Paper  0.37
# 995     Office Furnishings  0.57
# 996   Computer Peripherals  0.42
# ...

# %%
df1.to_csv("test.csv")

# %%
pwd()
# Out:
# 'C:\\Users\\Muhammad Hamza Abid'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FACE-682C
#
#  Directory of C:\Users\Muhammad Hamza Abid
#
# 15/05/2022  09:50 pm    <DIR>          .
# 15/05/2022  09:50 pm    <DIR>          ..
# 13/05/2022  03:47 pm    <DIR>          .astropy
# 26/04/2022  08:21 pm    <DIR>          .conda
# 30/03/2022  09:36 pm                25 .condarc
# 30/03/2022  09:35 pm    <DIR>          .continuum
# 15/05/2022  08:19 pm    <DIR>          .ipynb_checkpoints
# 30/03/2022  09:39 pm    <DIR>          .ipython
# 19/04/2022  08:42 pm    <DIR>          .jupyter
# 13/05/2022  03:53 pm    <DIR>          .matplotlib
# 30/03/2022  11:37 pm                19 .python_history
# 20/04/2022  02:18 pm    <DIR>          __pycache__
# 13/03/2021  02:12 am    <DIR>          3D Objects
# 20/04/2022  02:04 pm                98 addition.py
# 30/03/2022  09:29 pm    <DIR>          anaconda3
# 13/03/2021  02:12 am    <DIR>          Contacts
# 18/05/2021  11:00 pm    <DIR>          Desktop
# ...

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0  1   Eldon Base for stackable storage shelf, platinum  \
# 0           0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1           1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2           2  4                                               R380
# 3           3  5                           Holmes HEPA Air Purifier
# 4           4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
#
#   Muhammed MacIntyre    3  -213.25   38.94     35  Nunavut  \
# 0       Barry French  293   457.81  208.16  68.02  Nunavut
# 1       Barry French  293    46.71    8.69   2.99  Nunavut
# 2      Clay Rozendal  483  1198.97  195.99   3.99  Nunavut
# 3     Carlos Soltero  515    30.94   21.78   5.94  Nunavut
# 4     Carlos Soltero  515     4.43    6.64   4.95  Nunavut
#
#            Storage & Organization   0.8
# 0                      Appliances  0.58
# 1  Binders and Binder Accessories  0.39
# 2    Telephones and Communication  0.58
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample-Spreadsheet-1000-rows.csv', encoding = 'latin1')

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#')
df
# Separting the data by #
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#', header = None)
df

# Remove the column header
# Out:
#                  0                                 1                2  \
# 0    Serial Number                      Company Name  Employee Markme
# 1    9788189999599                    TALES OF SHIVA             Mark
# 2    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 3    9780198082897                          MY KUMAN             Mark
# 4    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# ..             ...                               ...              ...
# 995  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 996  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 997  9781730155116              SHRI KRISHMark LEELA             Mark
# 998  9789350891896                MENTAL MATHEMATICS             Mark
# 999  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                                       3      4
# 0                           Description  Leave
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#', header = None, names= ['A', 'B','C','D','E'])
df
# Giving own names of column
# Out:
#                  A                                 B                C  \
# 0    Serial Number                      Company Name  Employee Markme
# 1    9788189999599                    TALES OF SHIVA             Mark
# 2    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 3    9780198082897                          MY KUMAN             Mark
# 4    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# ..             ...                               ...              ...
# 995  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 996  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 997  9781730155116              SHRI KRISHMark LEELA             Mark
# 998  9789350891896                MENTAL MATHEMATICS             Mark
# 999  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                                       D      E
# 0                           Description  Leave
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#', header = None, names= ['A', 'B','C','D','E'], skiprows=[0,4,6,8])
df
# Skip rows
# Out:
#                  A                                 B                C  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780545060455                  THE BLACK CIRCLE             Mark
# 4    9789381626610                 CHAMarkKYA MANTRA             Mark
# ..             ...                               ...              ...
# 991  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 992  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 993  9781730155116              SHRI KRISHMark LEELA             Mark
# 994  9789350891896                MENTAL MATHEMATICS             Mark
# 995  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                                       D  E
# 0                                  mark  0
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#' , na_values=['Mark', 'ARUNDHATI ROY'])
df
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA              NaN
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN              NaN
# 3    9780007880331           THE GOD OF SMAAL THINGS              NaN
# 4    9780545060455                  THE BLACK CIRCLE              NaN
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS              NaN
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA              NaN
# 997  9789350891896                MENTAL MATHEMATICS              NaN
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#')
df
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
df.describe()
# Out:
#        Serial Number       Leave
# count   9.990000e+02  999.000000
# mean    9.649954e+12    0.971972
# std     1.150065e+12    2.198381
# min     8.170110e+09    0.000000
# 25%     9.788127e+12    0.000000
# 50%     9.788188e+12    0.000000
# 75%     9.789383e+12    1.000000
# max     9.798170e+12   10.000000

# %%
df.dtypes
# Out:
# Serial Number       int64
# Company Name       object
# Employee Markme    object
# Description        object
# Leave               int64
# dtype: object

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#')
print(df)
df.to_csv("result.csv", index = False, header = False, sep = "#")
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
df.to_csv("result_1.csv", index = False, columns = ['Company Name', 'Description'])

# %%
df = pd.read_csv('E:\Pictures\Sample1000.csv', sep = '#')
df
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
df.tail()
# Out:
#      Serial Number                      Company Name Employee Markme  \
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS            Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE     Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA            Mark
# 997  9789350891896                MENTAL MATHEMATICS            Mark
# 998  9789383182008            MATHEMATICS CLASS 10th     R.D. SHARMA
#
#                             Description  Leave
# 994  DEEPAK SERIES FOR TEST PREPARATION      0
# 995                         Definitions      0
# 996                          DEREAMLAND      0
# 997                          DEREAMLAND      0
# 998                     DHANPAT RAI &CO      5

# %%
df.columns
# Out:
# Index(['Serial Number', 'Company Name', 'Employee Markme', 'Description',
#        'Leave'],
#       dtype='object')

# %%
df['Serial Number']
# Out:
# 0      9788189999599
# 1      9780099578079
# 2      9780198082897
# 3      9780007880331
# 4      9780545060455
#            ...
# 994    9788192778792
# 995    9781862305274
# 996    9781730155116
# 997    9789350891896
# 998    9789383182008
# Name: Serial Number, Length: 999, dtype: int64

# %%
type(df['Serial Number'])
# Out:
# pandas.core.series.Series

# %%
df[['Serial Number']]
# Out:
#      Serial Number
# 0    9788189999599
# 1    9780099578079
# 2    9780198082897
# 3    9780007880331
# 4    9780545060455
# ..             ...
# 994  9788192778792
# 995  9781862305274
# 996  9781730155116
# 997  9789350891896
# 998  9789383182008
#
# [999 rows x 1 columns]

# %%
type(df[['Serial Number']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Serial Number', 'Company Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Serial Number', 'Company Name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[['Serial Number', 'Company Name']]
# Out:
#      Serial Number                      Company Name
# 0    9788189999599                    TALES OF SHIVA
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY
# 2    9780198082897                          MY KUMAN
# 3    9780007880331           THE GOD OF SMAAL THINGS
# 4    9780545060455                  THE BLACK CIRCLE
# ..             ...                               ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE
# 996  9781730155116              SHRI KRISHMark LEELA
# 997  9789350891896                MENTAL MATHEMATICS
# 998  9789383182008            MATHEMATICS CLASS 10th
#
# [999 rows x 2 columns]

# %%
df[['Description', 'Company Name', 'Leave', 'Serial Number']]
# Out:
#                             Description                      Company Name  \
# 0                                  mark                    TALES OF SHIVA
# 1                                  Mark         1Q84 THE COMPLETE TRILOGY
# 2                                  Mark                          MY KUMAN
# 3                    4TH HARPER COLLINS           THE GOD OF SMAAL THINGS
# 4                    4TH HARPER COLLINS                  THE BLACK CIRCLE
# ..                                  ...                               ...
# 994  DEEPAK SERIES FOR TEST PREPARATION  CURRENT AFFAIRS 49 PRACTICE SETS
# 995                         Definitions   BOY IN THE STRIPED PYJAMAS  THE
# 996                          DEREAMLAND              SHRI KRISHMark LEELA
# 997                          DEREAMLAND                MENTAL MATHEMATICS
# 998                     DHANPAT RAI &CO            MATHEMATICS CLASS 10th
#
#      Leave  Serial Number
# 0        0  9788189999599
# ...

# %%
import pandas as pd
pd.read_excel('E:\Sample\Business.xlsx', sheet_name = 'Add your take on balances')
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
import pandas as pd
df2 = pd.read_excel('E:\Sample\Business.xlsx', sheet_name = 'Create your instrument universe')
df2
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3     Active
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8     Active
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8     Active
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57     Active
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05     Active
#
# ...

# %%
df3 = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')
df3
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 6

# %%
df3[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df3[3]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS      MP     FG     FGA  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0    35.0  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0   145.0  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0   159.0  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0   135.0  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0   147.0  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0   163.0  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0   130.0  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0    72.0  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0   193.0  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0   110.0  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0     6.0  ...
# ...

# %%
df3[3].to_csv('player_data.csv')

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name":"sudh",
"phone_num":45643567,
"comp":["iNeuron", "EY", "Unilever", "Verizone","deliotte", "wipro"]
}

"""

# %%
import json

# %%
s1 = json.loads(s)
s1
# Out:
# {'name': 'sudh',
#  'phone_num': 45643567,
#  'comp': ['iNeuron', 'EY', 'Unilever', 'Verizone', 'deliotte', 'wipro']}

# %%
pd.DataFrame(s1)
# Out:
#    name  phone_num      comp
# 0  sudh   45643567   iNeuron
# 1  sudh   45643567        EY
# 2  sudh   45643567  Unilever
# 3  sudh   45643567  Verizone
# 4  sudh   45643567  deliotte
# 5  sudh   45643567     wipro

# %%
pd.DataFrame(s1, columns=['comp'])
# Out:
#        comp
# 0   iNeuron
# 1        EY
# 2  Unilever
# 3  Verizone
# 4  deliotte
# 5     wipro

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47032',
#   'id': 1236352230,
#   'node_id': 'PR_kwDOAA0YD8431mtS',
#   'number': 47032,
#   'title': 'CI: Start Testing on Python 3.11',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47032/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/47032',
#  'id': 1236352230,
#  'node_id': 'PR_kwDOAA0YD8431mtS',
#  'number': 47032,
#  'title': 'CI: Start Testing on Python 3.11',
#  'user': {'login': 'lithomas1',
#   'id': 47963215,
#   'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lithomas1',
#   'html_url': 'https://github.com/lithomas1',
#   'followers_url': 'https://api.github.com/users/lithomas1/followers',
# ...

# %%
js[0]['title']
# Out:
# 'CI: Start Testing on Python 3.11'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# CI: Start Testing on Python 3.11
# DOC: DataFrame.rename Method
# Fix: Pandas rolling removes imaginary part of complex
# DOC: Clarify decay argument validation in ewm when times is provided
# DEPR: groupby numeric_only default
# BUG: read_csv not guessing delimiter
# ASV Bug ? After commit 009c4c62.
# DOC: Fix some typos in pandas/.
# REF: merge datetime_to_datetime64 into array_to_datetime
# ENH: implement DateOffset + datetime64 array
# BUG: pandas accepts non-increasing MultiIndex header arguments
# TYP: resolve mypy ingores in core/indexing.py
# BUG: sort_index cause UnicodeDecodeError in non utf-8 locales
# BUG: dataframe with datetimeindex as index, when indexing columns interprets some strings as datetimes
# BUG: PeriodIndex looses tz information
# Simplify Timedelta init, standardize overflow errors
# ewm check for mutually exclusive arguments doesn't work when times argument is present
# BUG: Allow using datetime64[ns, UTC] in IntervalDtype
# ...

# %%
pd.DataFrame(js, columns = ['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df5 = pd.DataFrame(js)

# %%
df5.to_csv('json_dump.csv')

# %%
us = js[0]['user']

# %%
us
# Out:
# {'login': 'lithomas1',
#  'id': 47963215,
#  'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lithomas1',
#  'html_url': 'https://github.com/lithomas1',
#  'followers_url': 'https://api.github.com/users/lithomas1/followers',
#  'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#  'repos_url': 'https://api.github.com/users/lithomas1/repos',
#  'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#  'type': 'User',
# ...

# %%
json(us)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_980/897224188.py in <module>
# ----> 1 json(us)
#
# TypeError: 'module' object is not callable

# %%
l=[]
for i in range(len(js)):
    l.append(js[i]['user'])
pd.DataFrame(l)
# Out:
#               login        id               node_id  \
# 0         lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 1          MischaDy  44754681  MDQ6VXNlcjQ0NzU0Njgx
# 2           weikhor  36619387  MDQ6VXNlcjM2NjE5Mzg3
# 3         mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4        rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 5         Gabriel-p   6054951  MDQ6VXNlcjYwNTQ5NTE=
# 6            smarie   3236794  MDQ6VXNlcjMyMzY3OTQ=
# 7          Yulv-git  34329208  MDQ6VXNlcjM0MzI5MjA4
# 8      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9           hottwaj   5629061  MDQ6VXNlcjU2MjkwNjE=
# 10        ahawryluk  50434302  MDQ6VXNlcjUwNDM0MzAy
# 11           iasoon   6320308  MDQ6VXNlcjYzMjAzMDg=
# 12           zdenop    574156  MDQ6VXNlcjU3NDE1Ng==
# 13       JamesHowse  40427038  MDQ6VXNlcjQwNDI3MDM4
# 14          joooeey  28426758  MDQ6VXNlcjI4NDI2NzU4
# 15   patrickmckenna   3589536  MDQ6VXNlcjM1ODk1MzY=
# 16         trimcrae  22642433  MDQ6VXNlcjIyNjQyNDMz
# ...

# %%
import pandas as pd
